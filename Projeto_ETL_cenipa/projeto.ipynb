# %%
import pandas as pnd
import pandera as pad

# %%
data = pnd.read_csv('ocorrencias.csv',sep=';',parse_dates=['ocorrencia_dia'], dayfirst =True)#le o arquivo com o separador e ve uma das var como data
data.head() #imprime as 5 primeiras linhas
#data.tail() imprime os 5 ultimos aceita argumentos
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                  **                   **      RIO DE JANEIRO            RJ
# ...

# %% [raw]
# data.dtypes #mostra o tipo dos dados
# data.ocorrencia_dia.dt.month #pega o dia

# %%
schema = pad.DataFrameSchema(
    columns={
        "codigo":pad.Column(pad.Int, required=False),
        "codigo_ocorrencia":pad.Column(pad.Int),
        "ocorrencia_uf": pad.Column(pad.String, pad.Check.str_length(2,2)),
        "ocorrencia_dia": pad.Column(pad.DateTime, nullable = True),
        "ocorrencia_hora": pad.Column(pad.String,pad.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'),nullable = True)
    }
)#valida se os dados presentes estão verdades

# %%
try:
    schema.validate(data)#valida se esta tudo ok, se tiver dados errados retorna um erro
except BaseException as ex:
    print('Erro na formatação dos dados: {}'.format(ex))
else:
    print('Dados OK')
# Out:
# Dados OK
